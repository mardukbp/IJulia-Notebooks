# %%
using PyPlot
using SymPy
# Out:
# INFO: Loading help data...
# ...

# %%
m = sym"m"

f(t)=(1/10)+(1/pi)*SymPy.summation((sin(m*pi/5)*cos(m*pi*t/5)+sin(m*pi*t/5)-cos(m*pi/5)*sin(m*pi*t/5))/m, (m, 1, 5))
# Out:
# f (generic function with 1 method)

# %%
u = [-5:0.01:5]
fourier = [float(f(i)) for i in u];

# %%
plot(u,fourier);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f4b82c91c88>)
